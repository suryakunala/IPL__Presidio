# %%
import numpy as np
import pandas as pd

# %%
cd /content/drive/MyDrive/presidio/data
# Out:
# /content/drive/MyDrive/presidio/data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#dataTables
ball_by_ball=pd.read_csv('Ball_by_Ball.csv')
matchData=pd.read_csv('Match.csv')
PlayerData=pd.read_csv('Player.csv')
SeasonData=pd.read_csv('Season.csv')
TeamData=pd.read_csv('Team.csv')

# %%
matchData.groupby()
# Out:
#      Match_Id Match_Date  ...   City_Name  Host_Country
# 0      335987  18-Apr-08  ...   Bangalore         India
# 1      335988  19-Apr-08  ...  Chandigarh         India
# 2      335989  19-Apr-08  ...       Delhi         India
# 3      335990  20-Apr-08  ...      Mumbai         India
# 4      335991  20-Apr-08  ...     Kolkata         India
# ..        ...        ...  ...         ...           ...
# 572    981016  22-May-16  ...      Raipur         India
# 573    981018  24-May-16  ...   Bangalore         India
# 574    981020  25-May-16  ...       Delhi         India
# 575    981022  27-May-16  ...       Delhi         India
# 576    981024  29-May-16  ...   Bangalore         India
#
# [577 rows x 19 columns]

# %%
c=matchData.groupby('Venue_Name')

# %%
stadiumData=[]
for stadium,index in c.groups.items():
    j,k=0,0
    for ind in index:
        a=list(matchData.loc[ind,['Toss_Decision','Win_Type']])
        #print(a)
        if a[0]=='field':
            j+=1
        if a[1]=='by wickets':
            k+=1
    
    stadiumData.append([stadium,j,k,len(index)])

# %%
c.groups.items()

# %%
stadiumData=pd.DataFrame(stadiumData,columns=['stadiumName','tossWonChoseField','chaseWon','Total'])

# %%
stadiumData
# Out:
#                                           stadiumName  ...  Total
# 0                                    Barabati Stadium  ...      7
# 1                                   Brabourne Stadium  ...     11
# 2                                        Buffalo Park  ...      3
# 3                               De Beers Diamond Oval  ...      3
# 4                          Dr DY Patil Sports Academy  ...     17
# 5   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  ...     11
# 6                 Dubai International Cricket Stadium  ...      7
# 7                                        Eden Gardens  ...     54
# 8                                    Feroz Shah Kotla  ...     53
# 9                                          Green Park  ...      2
# 10       Himachal Pradesh Cricket Association Stadium  ...      9
# 11                             Holkar Cricket Stadium  ...      2
# 12                 JSCA International Stadium Complex  ...      7
# ...

# %%
stadiumData['tossWonChoseField']=stadiumData['tossWonChoseField']/stadiumData['Total']

# %%
stadiumData['chaseWon']=stadiumData['chaseWon']/stadiumData['Total']

# %%
stadiumData.tail()
# Out:
#                                      stadiumName  ...  Total
# 30                              St George's Park  ...      7
# 31                    Subrata Roy Sahara Stadium  ...     17
# 32                               SuperSport Park  ...     12
# 33  Vidarbha Cricket Association Stadium, Jamtha  ...      3
# 34                              Wankhede Stadium  ...     49
#
# [5 rows x 4 columns]

# %%
stadiumData.to_csv('stadiumData.csv')

# %%
list(matchData.loc[0,['Toss_Decision','Win_Type']])
# Out:
# ['field', 'by runs']

# %%
stadiumData=pd.DataFrame(stadiumData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ad8e0eb874bb> in <module>()
# ----> 1 stadiumData=pd.DataFrame(stadiumData)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ...
